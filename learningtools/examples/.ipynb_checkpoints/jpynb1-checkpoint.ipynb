# %% [markdown]
# # jpynb1: Printing Basics
#
# This notebook is structured like a small Kaggle Learn lesson.
#
# You read a short prompt, edit the starter code in each exercise cell, and then use `q1.check()` or `q2.check()` to validate your answer. Hints and solutions remain available through the question objects.

# %%
import os
while True:
    workspace = os.getcwd()
    if os.path.basename(workspace) == "RobotFramework_AIO":
        print(f"Workspace: {workspace}")
        os.chdir(workspace)
        break
    else:
        os.chdir("..")
try:
    LEARNINGTOOLS_NOTEBOOK = __vsc_ipynb_file__
except NameError:
    LEARNINGTOOLS_NOTEBOOK = "jpynb1.ipynb"

from learningtools import *

lesson
# Out:
# <Lesson jpynb1>

# %% [markdown]
# ## Exercise 1
#
# Print the exact answer for the first exercise.
#
# If you want to re-open the prompt from Python, run `q1.prompt()` in a new cell.

# %%
# TODO: Change the message (expected "jpynb1 q1")
print("Your message here!")

# Uncomment to get a hint
# q1.hint()

# Uncomment to view solution
# q1.solution()

# DO NOT REMOVE: Mark this question as completed
q1.check()

# %% [markdown]
# ## Exercise 2
#
# Repeat the same pattern for the second answer.
#
# Use `q2.hint()` or `q2.solution()` if you need help.

# %%
# TODO: Change the message (expected "jpynb1 q2")
print("Your message here!")

# Uncomment to get a hint
# q2.hint()

# Uncomment to view solution
# q2.solution()

# DO NOT REMOVE: Mark this question as completed
q2.check()

# %% [markdown]
# ## Lesson Progress
#
# Use the final cell to render a lesson-style progress summary after you complete the exercises.

# %%
get_progress(current_workbook_name())
