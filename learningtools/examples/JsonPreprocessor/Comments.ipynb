# %% [markdown]
# # Comments: JSONP Comment Syntax
#
# This lesson shows how `//` comments and `/* ... */` comment blocks are removed before JsonPreprocessor parses the content.
#
# Run the bootstrap cell first, then complete each exercise and validate it with `p1.check()` or `p2.check()`.

# %%
import os
while True:
    workspace = os.getcwd()
    if os.path.basename(workspace) == "RobotFramework_AIO":
        os.chdir(workspace)
        break
    else:
        os.chdir("..")
        
LEARNINGTOOLS_NOTEBOOK = "JsonPreprocessor.Comments"

from learningtools import *
from JsonPreprocessor.CJsonPreprocessor import CJsonPreprocessor

activate(LEARNINGTOOLS_NOTEBOOK)
lesson

# %% [markdown]
# ## Exercise 1
#
# Print the parsed value of the JSON content below after the inline comment is ignored.
#
# ```json
# {
#     "name" : "JPP comments",
#     "version" : "1.0.0"
# }

# %%
# Define the JSONP content with comments here
content = '''
{
<define your JSONP content with comments here>
}
'''
json_object = CJsonPreprocessor(syntax="python").json_loads(content)

p1.check()

# %%
p1.hint()
# p1.solution()

# %% [markdown]
# ## Exercise 2
#
# Print the last surviving list item after the block comment is removed.

# %%
from JsonPreprocessor.CJsonPreprocessor import CJsonPreprocessor

content = '''
{
<define your JSONP content with comments here>
}
'''
json_object = CJsonPreprocessor(syntax="python").json_loads(content)

p1.check()

# %%
p1.hint()
# p1.solution()

# %% [markdown]
# ## Lesson Progress
#
# Render the current completion state for this lesson.

# %%
lesson.progress()
